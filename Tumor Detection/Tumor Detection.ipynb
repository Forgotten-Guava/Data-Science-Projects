# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

tumor_df = pd.read_csv('tumor detection.csv')
X = tumor_df.drop('Target', axis=1).values
y = tumor_df['Target'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print("KNN Tumor Classification")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Benign', 'Malignant']))
# Out:
# KNN Tumor Classification
# Accuracy: 0.78
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.67      1.00      0.80         4
#    Malignant       1.00      0.60      0.75         5
#
#     accuracy                           0.78         9
#    macro avg       0.83      0.80      0.78         9
# weighted avg       0.85      0.78      0.77         9
